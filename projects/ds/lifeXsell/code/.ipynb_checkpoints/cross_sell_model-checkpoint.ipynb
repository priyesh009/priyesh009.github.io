# %% [markdown]
# # Life Insurance Cross-Sell Prediction
#
# This notebook demonstrates an end-to-end machine learning workflow for predicting which existing insurance customers are most likely to purchase life insurance.
# We use a synthetic dataset (`cross_sell_data.csv`) to simulate real-world cross-sell modeling.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

# %%
# Load dataset
df = pd.read_csv('cross_sell_data.csv')
df.head()
# Out:
#    customer_id  age income_bracket  num_home_policies  num_auto_policies  \
# 0            1   63            Low                  2                  2
# 1            2   53           High                  0                  2
# 2            3   39         Medium                  1                  1
# 3            4   67            Low                  1                  1
# 4            5   32         Medium                  3                  1
#
#    num_farm_policies  claims_last_year  life_policies_2024  \
# 0                  0                 0                   0
# 1                  0                 0                   0
# 2                  0                 0                   0
# 3                  0                 0                   0
# 4                  2                 0                   0
#
#    life_policies_2025  cross_sell_flag
# 0                   1                1
# 1                   1                1
# 2                   1                1
# 3                   1                1
# 4                   1                1

# %%
# Exploratory Data Analysis
print(df.describe(include='all'))

# Distribution of target
sns.countplot(data=df, x='cross_sell_flag')
plt.title('Cross-Sell Target Distribution')
plt.show()

# Age distribution
sns.histplot(df['age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.show()
# Out:
#         customer_id         age income_bracket  num_home_policies  \
# count    200.000000  200.000000            200         200.000000
# unique          NaN         NaN              3                NaN
# top             NaN         NaN         Medium                NaN
# freq            NaN         NaN             98                NaN
# mean     100.500000   47.885000            NaN           0.745000
# std       57.879185   13.491176            NaN           0.820574
# min        1.000000   25.000000            NaN           0.000000
# 25%       50.750000   36.000000            NaN           0.000000
# 50%      100.500000   48.500000            NaN           1.000000
# 75%      150.250000   60.000000            NaN           1.000000
# max      200.000000   69.000000            NaN           3.000000
#
#         num_auto_policies  num_farm_policies  claims_last_year  \
# count          200.000000         200.000000        200.000000
# unique                NaN                NaN               NaN
# top                   NaN                NaN               NaN
# freq                  NaN                NaN               NaN
# mean             1.050000           0.345000          0.185000
# std              0.996224           0.581088          0.389272
# min              0.000000           0.000000          0.000000
# 25%              0.000000           0.000000          0.000000
# 50%              1.000000           0.000000          0.000000
# 75%              2.000000           1.000000          0.000000
# max              4.000000           3.000000          1.000000
#
#         life_policies_2024  life_policies_2025  cross_sell_flag
# count           200.000000           200.00000       200.000000
# unique                 NaN                 NaN              NaN
# top                    NaN                 NaN              NaN
# freq                   NaN                 NaN              NaN
# mean              0.215000             0.67500         0.460000
# std               0.411853             0.61748         0.499648
# min               0.000000             0.00000         0.000000
# 25%               0.000000             0.00000         0.000000
# 50%               0.000000             1.00000         0.000000
# 75%               0.000000             1.00000         1.000000
# max               1.000000             2.00000         1.000000

# %%
# Encode categorical variable
df_encoded = df.copy()
le = LabelEncoder()
df_encoded['income_bracket'] = le.fit_transform(df_encoded['income_bracket'])

# Features and target
X = df_encoded.drop(columns=['customer_id','cross_sell_flag','life_policies_2024','life_policies_2025'])
y = df_encoded['cross_sell_flag']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=500),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, random_state=42)
}

results = {}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:,1]
    auc = roc_auc_score(y_test, y_proba)
    print(f"\n{name} - AUC: {auc:.3f}")
    print(classification_report(y_test, y_pred))
    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.title(f'{name} - Confusion Matrix')
    plt.show()
# Out:
# Logistic Regression - AUC: 0.616
#               precision    recall  f1-score   support
#
#            0       0.62      0.75      0.68        32
#            1       0.62      0.46      0.53        28
#
#     accuracy                           0.62        60
#    macro avg       0.62      0.61      0.60        60
# weighted avg       0.62      0.62      0.61        60
# Random Forest - AUC: 0.646
#               precision    recall  f1-score   support
#
#            0       0.58      0.56      0.57        32
#            1       0.52      0.54      0.53        28
#
#     accuracy                           0.55        60
#    macro avg       0.55      0.55      0.55        60
# weighted avg       0.55      0.55      0.55        60
# Gradient Boosting - AUC: 0.622
#               precision    recall  f1-score   support
#
#            0       0.65      0.75      0.70        32
#            1       0.65      0.54      0.59        28
#
#     accuracy                           0.65        60
#    macro avg       0.65      0.64      0.64        60
# weighted avg       0.65      0.65      0.65        60

# %%
# Feature importance from Random Forest
rf = models['Random Forest']
importances = pd.Series(rf.feature_importances_, index=X.columns)
importances.sort_values().plot(kind='barh')
plt.title('Feature Importance - Random Forest')
plt.show()

# %%
# Business Insights
var = """
Key takeaways:
- Gradient Boosting / Random Forest typically outperform Logistic Regression in predictive power.
- Policy mix (number of home/auto/farm policies) and income bracket are strong indicators of cross-sell success.
- Customers with no recent claims are more receptive to new offers.
"""
print(var)
# Out:
# Key takeaways:
# - Gradient Boosting / Random Forest typically outperform Logistic Regression in predictive power.
# - Policy mix (number of home/auto/farm policies) and income bracket are strong indicators of cross-sell success.
# - Customers with no recent claims are more receptive to new offers.
